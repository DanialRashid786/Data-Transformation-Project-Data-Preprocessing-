# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler

# %%
# pd.set_option('display.max_rows',None)

# %%
df = pd.read_excel('C:/Users/dania/Desktop/python/Data_Analysis/Employee(Dataset)/emp_dataset.xlsx')
df
# Out:
#     Employee ID         Full Name                   Job Title   Department  \
# 0        E02002            Kai Le           Controls Engineer  Engineering
# 1        E02003      Robert Patel                     Analyst        Sales
# 2        E02004        Cameron Lo       Network Administrator           IT
# 3        E02005   Harper Castillo        IT Systems Architect           IT
# 4        E02006  Harper Dominguez                    Director  Engineering
# ..          ...               ...                         ...          ...
# 961      E02250          Mila Han                     Manager        Sales
# 962      E02251   Genesis Herrera                     Manager           IT
# 963      E02252    Olivia Vazquez            Network Engineer           IT
# 964      E02253        Leilani Ng             Systems Analyst           IT
# 965      E02254    Olivia Mendoza  Sr. Account Representative        Sales
#
# ...

# %%
df.shape
# Out:
# (966, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 966 entries, 0 to 965
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Employee ID    966 non-null    object
#  1   Full Name      966 non-null    object
#  2   Job Title      966 non-null    object
#  3   Department     966 non-null    object
#  4   Business Unit  966 non-null    object
#  5   Gender         966 non-null    object
#  6   Ethnicity      966 non-null    object
#  7   Age            966 non-null    int64
#  8   Hire Date      966 non-null    object
#  9   Annual Salary  966 non-null    int64
#  10  Bonus %        966 non-null    float64
#  11  Country        966 non-null    object
#  12  City           966 non-null    object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 98.2+ KB

# %%
df.head()
# Out:
#   Employee ID         Full Name              Job Title   Department  \
# 0      E02002            Kai Le      Controls Engineer  Engineering
# 1      E02003      Robert Patel                Analyst        Sales
# 2      E02004        Cameron Lo  Network Administrator           IT
# 3      E02005   Harper Castillo   IT Systems Architect           IT
# 4      E02006  Harper Dominguez               Director  Engineering
#
#             Business Unit  Gender Ethnicity  Age   Hire Date  Annual Salary  \
# 0           Manufacturing    Male     Asian   47  05-02-2022          92368
# 1               Corporate    Male     Asian   58  23-10-2013          45703
# 2  Research & Development    Male     Asian   34  24-03-2019          83576
# 3               Corporate  Female    Latino   39  07-04-2018          98062
# 4               Corporate  Female    Latino   42  18-06-2005         175391
#
#    Bonus %        Country      City
# 0     0.00  United States  Columbus
# ...

# %%
df
# Out:
#     Employee ID         Full Name                   Job Title   Department  \
# 0        E02002            Kai Le           Controls Engineer  Engineering
# 1        E02003      Robert Patel                     Analyst        Sales
# 2        E02004        Cameron Lo       Network Administrator           IT
# 3        E02005   Harper Castillo        IT Systems Architect           IT
# 4        E02006  Harper Dominguez                    Director  Engineering
# ..          ...               ...                         ...          ...
# 961      E02250          Mila Han                     Manager        Sales
# 962      E02251   Genesis Herrera                     Manager           IT
# 963      E02252    Olivia Vazquez            Network Engineer           IT
# 964      E02253        Leilani Ng             Systems Analyst           IT
# 965      E02254    Olivia Mendoza  Sr. Account Representative        Sales
#
# ...

# %%
df['Monthly Salary'] = (df['Annual Salary'].astype(float) / 12).round(0)
df['Monthly Salary']
df
# Out:
#     Employee ID         Full Name                   Job Title   Department  \
# 0        E02002            Kai Le           Controls Engineer  Engineering
# 1        E02003      Robert Patel                     Analyst        Sales
# 2        E02004        Cameron Lo       Network Administrator           IT
# 3        E02005   Harper Castillo        IT Systems Architect           IT
# 4        E02006  Harper Dominguez                    Director  Engineering
# ..          ...               ...                         ...          ...
# 961      E02250          Mila Han                     Manager        Sales
# 962      E02251   Genesis Herrera                     Manager           IT
# 963      E02252    Olivia Vazquez            Network Engineer           IT
# 964      E02253        Leilani Ng             Systems Analyst           IT
# 965      E02254    Olivia Mendoza  Sr. Account Representative        Sales
#
# ...

# %%
df
# Out:
#     Employee ID         Full Name                   Job Title   Department  \
# 0        E02002            Kai Le           Controls Engineer  Engineering
# 1        E02003      Robert Patel                     Analyst        Sales
# 2        E02004        Cameron Lo       Network Administrator           IT
# 3        E02005   Harper Castillo        IT Systems Architect           IT
# 4        E02006  Harper Dominguez                    Director  Engineering
# ..          ...               ...                         ...          ...
# 961      E02250          Mila Han                     Manager        Sales
# 962      E02251   Genesis Herrera                     Manager           IT
# 963      E02252    Olivia Vazquez            Network Engineer           IT
# 964      E02253        Leilani Ng             Systems Analyst           IT
# 965      E02254    Olivia Mendoza  Sr. Account Representative        Sales
#
# ...

# %% [markdown]
# # Normalization [0,1] range

# %%
data = df[['Age','Monthly Salary']]
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(data)
normalized_data
# Out:
# array([[0.55      , 0.23765534],
#        [0.825     , 0.02386451],
#        [0.225     , 0.1974046 ],
#        ...,
#        [0.7       , 0.24078962],
#        [0.575     , 0.04585945],
#        [0.45      , 0.21093149]])

# %%
df[["N_Age","N_Salary"]]=pd.DataFrame(normalized_data,columns=['Age','Monthly Salary'])

# %%
df.sort_values(['Age','Monthly Salary'])
# Out:
#     Employee ID        Full Name              Job Title   Department  \
# 580      E02582  Maverick Howard         IT Coordinator           IT
# 178      E02180      Aubrey Ruiz             Analyst II    Marketing
# 521      E02523    Liliana Lewis  Network Administrator           IT
# 346      E02348    Samantha Ford    Technical Architect           IT
# 325      E02327         Ivy Rios      Network Architect           IT
# ..          ...              ...                    ...          ...
# 872      E02203     Ellie Wilson               Director           IT
# 53       E02055       Layla Bell         Vice President  Engineering
# 481      E02483   Caroline Nunez         Vice President      Finance
# 888      E02483   Caroline Nunez         Vice President      Finance
# 910      E02483   Caroline Nunez         Vice President      Finance
#
#           Business Unit  Gender  Ethnicity  Age   Hire Date  Annual Salary  \
# ...

# %%
df = df[['Employee ID', 'Full Name', 'Job Title', 'Department', 'Business Unit', 'Gender', 'Ethnicity', 'Age', 'Hire Date', 'Annual Salary','Monthly Salary', 'Bonus %', 'Country', 'City', 'N_Age', 'N_Salary']]

# %%
df.sort_values('Monthly Salary')
# Out:
#     Employee ID        Full Name        Job Title   Department  \
# 10       E02012     Jameson Pena  Systems Analyst           IT
# 479      E02481    Caroline Wong          Analyst        Sales
# 908      E02481    Caroline Wong          Analyst        Sales
# 886      E02481    Caroline Wong          Analyst        Sales
# 84       E02086      Lucas Luong          Analyst    Marketing
# ..          ...              ...              ...          ...
# 182      E02184    Ariana Sharma   Vice President        Sales
# 833      E02256  Eloise Williams   Vice President        Sales
# 254      E02256  Eloise Williams   Vice President        Sales
# 331      E02333  Christopher Luu   Vice President  Engineering
# 555      E02557    Robert Rogers   Vice President  Engineering
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date  \
# 10            Manufacturing    Male     Latino   49  12-10-2003
# 479  Research & Development  Female      Asian   37  08-03-2017
# ...

# %% [markdown]
# # Encoding Categorical Variables

# %%
one_hot_encoded_data = pd.get_dummies(df, columns=['Ethnicity'])
one_hot_encoded_data
# Out:
#     Employee ID         Full Name                   Job Title   Department  \
# 0        E02002            Kai Le           Controls Engineer  Engineering
# 1        E02003      Robert Patel                     Analyst        Sales
# 2        E02004        Cameron Lo       Network Administrator           IT
# 3        E02005   Harper Castillo        IT Systems Architect           IT
# 4        E02006  Harper Dominguez                    Director  Engineering
# ..          ...               ...                         ...          ...
# 961      E02250          Mila Han                     Manager        Sales
# 962      E02251   Genesis Herrera                     Manager           IT
# 963      E02252    Olivia Vazquez            Network Engineer           IT
# 964      E02253        Leilani Ng             Systems Analyst           IT
# 965      E02254    Olivia Mendoza  Sr. Account Representative        Sales
#
# ...

# %% [markdown]
# #  Perform some aggregation on dataset

# %%
df.head()
# Out:
#   Employee ID         Full Name              Job Title   Department  \
# 0      E02002            Kai Le      Controls Engineer  Engineering
# 1      E02003      Robert Patel                Analyst        Sales
# 2      E02004        Cameron Lo  Network Administrator           IT
# 3      E02005   Harper Castillo   IT Systems Architect           IT
# 4      E02006  Harper Dominguez               Director  Engineering
#
#             Business Unit  Gender Ethnicity  Age   Hire Date  Annual Salary  \
# 0           Manufacturing    Male     Asian   47  05-02-2022          92368
# 1               Corporate    Male     Asian   58  23-10-2013          45703
# 2  Research & Development    Male     Asian   34  24-03-2019          83576
# 3               Corporate  Female    Latino   39  07-04-2018          98062
# 4               Corporate  Female    Latino   42  18-06-2005         175391
#
#    Monthly Salary  Bonus %        Country      City  N_Age  N_Salary  \
# ...

# %% [markdown]
# # Group by Department and calculate the average Annual Salary

# %%
avg_salary_by_dept = df.groupby('Department')['Annual Salary'].mean()
print(avg_salary_by_dept)
# Out:
# Department
# Accounting         124468.213592
# Engineering        108946.576000
# Finance            116658.727273
# Human Resources    121713.567308
# IT                  90684.773519
# Marketing          124536.436893
# Sales              106299.131034
# Name: Annual Salary, dtype: float64

# %% [markdown]
# # Group by Gender and calculate the total Bonus %:

# %%
total_bonus_by_gender = df.groupby('Gender')['Bonus %'].sum()
print(total_bonus_by_gender)
# Out:
# Gender
# Female    43.73
# Male      32.04
# Name: Bonus %, dtype: float64

# %% [markdown]
# # Group by Ethnicity and calculate the count of Employees:

# %%
count_by_ethnicity = df.groupby('Ethnicity')['Employee ID'].count()
print(count_by_ethnicity)
# Out:
# Ethnicity
# Asian        415
# Black         68
# Caucasian    214
# Latino       269
# Name: Employee ID, dtype: int64

# %% [markdown]
# # Group by Country and calculate the maximum Monthly Salary:

# %%
max_salary_by_country = df.groupby('Country')['Monthly Salary'].max()
print(max_salary_by_country)
# Out:
# Country
# Brazil           21457.0
# China            21383.0
# United States    21561.0
# Name: Monthly Salary, dtype: float64

# %%
# Group by Department and calculate mean salary and age
department_agg = df.groupby('Department').agg({
    'Annual Salary': 'mean',
    'Age': 'mean'
}).reset_index()
print(department_agg)
# Out:
#         Department  Annual Salary        Age
# 0       Accounting  124468.213592  45.417476
# 1      Engineering  108946.576000  45.672000
# 2          Finance  116658.727273  46.565657
# 3  Human Resources  121713.567308  45.615385
# 4               IT   90684.773519  44.501742
# 5        Marketing  124536.436893  41.786408
# 6            Sales  106299.131034  44.241379

# %%
# Create a pivot table to summarize average salary by Department and Gender
pivot_table = df.pivot_table(values='Annual Salary', index='Department', columns='Gender', aggfunc='mean')
print(pivot_table)
# Out:
# Gender                  Female           Male
# Department
# Accounting       117256.527273  132731.604167
# Engineering      116123.000000  101417.213115
# Finance          122691.358491  109708.086957
# Human Resources  119774.666667  124065.000000
# IT                90596.035971   90768.114865
# Marketing        132366.963636  115563.958333
# Sales            114717.142857   96766.970588

# %%
# Group by Department and Business Unit, then calculate sum of salaries
multi_agg = df.groupby(['Department', 'Business Unit']).agg({
    'Annual Salary': 'sum'
}).reset_index()
print(multi_agg)
# Out:
#          Department           Business Unit  Annual Salary
# 0        Accounting               Corporate        3200193
# 1        Accounting           Manufacturing        3079473
# 2        Accounting  Research & Development        3002882
# 3        Accounting      Specialty Products        3537678
# 4       Engineering               Corporate        3861849
# 5       Engineering           Manufacturing        2899624
# 6       Engineering  Research & Development        3824403
# 7       Engineering      Specialty Products        3032446
# 8           Finance               Corporate        3179877
# 9           Finance           Manufacturing        3457146
# 10          Finance  Research & Development        2373364
# 11          Finance      Specialty Products        2538827
# 12  Human Resources               Corporate        3569965
# 13  Human Resources           Manufacturing        1935402
# 14  Human Resources  Research & Development        3492102
# ...

# %%
# Define a custom aggregation function
def salary_range(series):
    return series.max() - series.min()

# Apply custom aggregation function
custom_agg = df.groupby('Department').agg({
    'Annual Salary': ['mean', 'sum', salary_range]
}).reset_index()
print(custom_agg)
# Out:
#         Department  Annual Salary
#                              mean       sum salary_range
# 0       Accounting  124468.213592  12820226       214957
# 1      Engineering  108946.576000  13618322       197491
# 2          Finance  116658.727273  11549214       213074
# 3  Human Resources  121713.567308  12658211       204922
# 4               IT   90684.773519  26026530       216093
# 5        Marketing  124536.436893  12827253       216518
# 6            Sales  106299.131034  15413374       217607

# %% [markdown]
# # Discretization

# %%
df['AgeGroup'] = pd.cut(df['Age'], bins=[0, 30, 60, 100], labels=['Young', 'Middle-aged', 'Senior'])
df
# Out:
#     Employee ID         Full Name                   Job Title   Department  \
# 0        E02002            Kai Le           Controls Engineer  Engineering
# 1        E02003      Robert Patel                     Analyst        Sales
# 2        E02004        Cameron Lo       Network Administrator           IT
# 3        E02005   Harper Castillo        IT Systems Architect           IT
# 4        E02006  Harper Dominguez                    Director  Engineering
# ..          ...               ...                         ...          ...
# 961      E02250          Mila Han                     Manager        Sales
# 962      E02251   Genesis Herrera                     Manager           IT
# 963      E02252    Olivia Vazquez            Network Engineer           IT
# 964      E02253        Leilani Ng             Systems Analyst           IT
# 965      E02254    Olivia Mendoza  Sr. Account Representative        Sales
#
# ...

# %% [markdown]
# # Binning

# %%
df['AgeBin'] = pd.cut(df['Age'], bins=[20, 40, 60, 80], labels=['20-40', '40-60', '60-80'])
df
# Out:
#     Employee ID         Full Name                   Job Title   Department  \
# 0        E02002            Kai Le           Controls Engineer  Engineering
# 1        E02003      Robert Patel                     Analyst        Sales
# 2        E02004        Cameron Lo       Network Administrator           IT
# 3        E02005   Harper Castillo        IT Systems Architect           IT
# 4        E02006  Harper Dominguez                    Director  Engineering
# ..          ...               ...                         ...          ...
# 961      E02250          Mila Han                     Manager        Sales
# 962      E02251   Genesis Herrera                     Manager           IT
# 963      E02252    Olivia Vazquez            Network Engineer           IT
# 964      E02253        Leilani Ng             Systems Analyst           IT
# 965      E02254    Olivia Mendoza  Sr. Account Representative        Sales
#
# ...
